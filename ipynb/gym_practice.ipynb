# %%
# !pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /home/sachchida/anaconda3/envs/rl/lib/python3.11/site-packages (from gymnasium) (2.4.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/sachchida/anaconda3/envs/rl/lib/python3.11/site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/sachchida/anaconda3/envs/rl/lib/python3.11/site-packages (from gymnasium) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 2.2 MB/s  0:00:00 eta 0:00:01
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gymnasium]
# Successfully installed farama-notifications-0.0.4 gymnasium-1.2.3

# %%
import gymnasium as gym

# %%
import gymnasium as gym

# Create an environment instance
env = gym.make("CartPole-v1", render_mode="human")

# Reset the environment
observation, info = env.reset(seed=42)

# Run an episode
for _ in range(1000):
    action = env.action_space.sample()  # sample a random action
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()

env.close()
# Out:
# /home/sachchida/anaconda3/envs/rl/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 12
#      10 for _ in range(1000):
#      11     action = env.action_space.sample()  # sample a random action
# ---> 12     observation, reward, terminated, truncated, info = env.step(action)
#      14     if terminated or truncated:
#      15         observation, info = env.reset()
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/gymnasium/wrappers/common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)    123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:223, in CartPoleEnv.step(self, action)
#     220     reward = -1.0 if self._sutton_barto_reward else 0.0
#     222 if self.render_mode == "human":
# --> 223     self.render()
#     225 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     226 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:337, in CartPoleEnv.render(self)
#     335 if self.render_mode == "human":
#     336     pygame.event.pump()
# --> 337     self.clock.tick(self.metadata["render_fps"])
#     338     pygame.display.flip()
#     340 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
